# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime

# %%
df=pd.read_csv("titanic data.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.drop(['PassengerId','Name','Ticket'],axis= 1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
print(177/891*100)
# Out:
# 19.865319865319865

# %%
sns.distplot(df['Age'])
# Out:
# <ipython-input-16-0fafe04ea3f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
print(df['Age'].mean(),"is the mean")
print(df['Age'].median(),"is the median")
print(df['Age'].mode(),"is the mode")
# Out:
# 29.69911764705882 is the mean
# 28.0 is the median
# 0    24.0
# Name: Age, dtype: float64 is the mode

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df[df['Age']>=65]
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 33          0       2  male  66.0      0      0  10.5000   NaN        S
# 54          0       1  male  65.0      0      1  61.9792   B30        C
# 96          0       1  male  71.0      0      0  34.6542    A5        C
# 116         0       3  male  70.5      0      0   7.7500   NaN        Q
# 280         0       3  male  65.0      0      0   7.7500   NaN        Q
# 456         0       1  male  65.0      0      0  26.5500   E38        S
# 493         0       1  male  71.0      0      0  49.5042   NaN        C
# 630         1       1  male  80.0      0      0  30.0000   A23        S
# 672         0       2  male  70.0      0      0  10.5000   NaN        S
# 745         0       1  male  70.0      1      1  71.0000   B22        S
# 851         0       3  male  74.0      0      0   7.7750   NaN        S

# %%
df['Age'].fillna(28,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
print(687/891*100)
# Out:
# 77.10437710437711

# %%
df.drop(['Cabin'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna("s",inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (775, 8)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
sns.boxplot(df['SibSp'])
# Out:
# <Axes: ylabel='SibSp'>

# %%
df[df['SibSp']==8]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch   Fare Embarked
# 159         0       3    male  28.0      8      2  69.55        S
# 180         0       3  female  28.0      8      2  69.55        S

# %%
sns.boxplot(df['Parch'])
# Out:
# <Axes: ylabel='Parch'>

# %%
df[df['Parch']>4]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 13          0       3    male  39.0      1      5  31.2750        S
# 25          1       3  female  38.0      1      5  31.3875        S
# 610         0       3  female  39.0      1      5  31.2750        S
# 638         0       3  female  41.0      0      5  39.6875        S
# 678         0       3  female  43.0      1      6  46.9000        S
# 885         0       3  female  39.0      0      5  29.1250        Q

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df[df['Fare']>450]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 258         1       1  female  35.0      0      0  512.3292        C
# 679         1       1    male  36.0      0      1  512.3292        C
# 737         1       1    male  35.0      0      0  512.3292        C

# %%
x = df[df['Pclass']==1]
sns.distplot(x['Fare'])
# Out:
# <ipython-input-38-f5a6efb11d93>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-39-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
genderwise_survival = df.groupby('Sex')['Survived'].value_counts().unstack()

# %%
genderwise_survival
# Out:
# Survived    0    1
# Sex
# female     76  216
# male      379  104

# %%
genderwise_survival.plot(kind='bar')
plt.show()

# %%
classwise_survival = df.groupby('Pclass')['Survived'].value_counts().unstack()
classwise_survival.plot(kind='bar')
plt.show()

# %%
citywise_survival = df.groupby('Embarked')['Survived'].value_counts().unstack()
citywise_survival.plot(kind='bar')
plt.show()
